# %% [markdown]
# DataSet: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews

# %% [markdown]
# **Get your Api token from kaggle**

# %% [markdown]
# 1- Go to Settings

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 2 - Download your API token (Create New Token)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# 3- Upload your kaggle.json file here in google colab

# %%
# !pip install kaggle

# %%
# configuring the path of Kaggle.json file
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %% [markdown]
# **Data Collection- Kaggle API**

# %% [markdown]
# Go to Dataset in kaggle and press Download
#
# Then choose Kaggle CLI and copy the command

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !kaggle datasets download -d lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# Out:
# Dataset URL: https://www.kaggle.com/datasets/lakshmi25npathi/imdb-dataset-of-50k-movie-reviews
# License(s): other
# imdb-dataset-of-50k-movie-reviews.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# unzip the dataset file
from zipfile import ZipFile
with ZipFile("/content/imdb-dataset-of-50k-movie-reviews.zip", "r") as zip_ref:
  zip_ref.extractall()
